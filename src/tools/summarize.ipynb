# %%
from summarize import expUtitVsK, execTimeVsSize, execTimeBreakDown, print_table
# Out:
# /Users/bcyl/FairPrescriptionRules/src/tools/summarize.py:146: SyntaxWarning: invalid escape sequence '\m'
#   """)

# %%
# Define output path
# Path should include full, triquarter, half, and quarter sized dateset
output_path = "/Users/bcyl/FairPrescriptionRules/output/so_gdp"
# Analyze effect of dataset size on execution time 
execTimeVsSize(output_path)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from summarize import *
# Define output path
# Path should include all variants
output_path = "/Users/bcyl/FairPrescriptionRules/output/credit_risk/gc_full"
# Analyze expected utilities over k
expUtitVsK(output_path)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 output_path = "/Users/bcyl/FairPrescriptionRules/output/credit_risk/gc_full"
#       5 # Analyze expected utilities over k
# ----> 6 expUtitVsK(output_path)
#
# File ~/FairPrescriptionRules/src/tools/summarize.py:42, in expUtitVsK(path)
#      40 i+=1
#      41 if 'cov' in v or 'cvrg' in v or 'fair' in v:
# ---> 42     plt.subplot(2, len(variants)/2, i)
#      43 else:
#      44     plt.subplot(3,3,i)
#
# File ~/FairPrescriptionRules/venv/lib/python3.12/site-packages/matplotlib/pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# ...

# %%
# Define output path
# Path should include all variants
output_path = "/Users/bcyl/FairPrescriptionRules/output/output/so_gdp/so_attribute_analysis"
# Analyze execution time break down 
execTimeBreakDown(output_path)
# Out:
# /Users/bcyl/FairPrescriptionRules/src/tools/summarize.py:146: SyntaxWarning: invalid escape sequence '\m'
#   """)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 output_path = "/Users/bcyl/FairPrescriptionRules/output/output/so_gdp/so_attribute_analysis"
#       4 # Analyze execution time break down
# ----> 5 execTimeBreakDown(output_path)
#
# File ~/FairPrescriptionRules/src/tools/summarize.py:65, in execTimeBreakDown(path)
#      63 def execTimeBreakDown(path):
#      64     variants = []
# ---> 65     for f in os.listdir(path):
#      66         if 'greedy' in f:
#      67             variants.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/bcyl/FairPrescriptionRules/output/output/so_gdp/so_attribute_analysis'

# %%
output_path = "/Users/bcyl/FairPrescriptionRules/output/gc_single_female/gc_coverage"
expUtitVsK(output_path)
execTimeBreakDown(output_path)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
output_path = "/Users/bcyl/FairPrescriptionRules/output/gc_single_female/gc_full"
print_table(output_path)
# Out:
# \midrule
# No constraints  & 17& 100.0\%& 100.0\%& 0.39& 0.39& 0.27& 0.12 \\
# Group coverage  &18& 100.0\%& 100.0\%& 0.39& 0.39& 0.3& 0.09 \\
# Rule coverage  & 6& 96.0\%& 100.0\%& 0.31& 0.31& 0.3& 0.01\\
# Group fairness  & 18& 100.0\%& 100.0\%& 0.39& 0.39& 0.3& 0.09 \\
# Individual fairness   & 20& 100.0\%& 100.0\%& 0.37& 0.37& 0.23& 0.14 \\
# Group coverage, Group fairness  & 6& 100.0\%& 100.0\%& 0.36& 0.37& 0.31& 0.06 \\
# Rule coverage, Group fairness  & 3& 90.0\%& 100.0\%& 0.29& 0.29& 0.31& -0.02\\
# Group coverage, Individual fairness  & 20& 100.0\%& 100.0\%& 0.37& 0.37& 0.23& 0.14\\
# Rule coverage, Individual fairness  &8& 96.8\%& 100.0\%& 0.29& 0.29& 0.23& 0.06 \\
