# %%
from summarize import *
# Out:
# /Users/bcyl/FairPrescriptionRules/src/tools/summarize.py:113: SyntaxWarning: invalid escape sequence '\m'
#   """)

# %%
# Define output path
# Path should include full, triquarter, half, and quarter sized dateset
output_path = "/Users/bcyl/FairPrescriptionRules/output/GDP"
# Analyze effect of dataset size on execution time 
execTimeVsSize(output_path)

# %%
# Define output path
# Path should include all variants
output_path = "/Users/bcyl/FairPrescriptionRules/output/GDP/so_full"
# Analyze expected utilities over k
expUtitVsK(output_path)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
# Define output path
# Path should include all variants
output_path = "/Users/bcyl/FairPrescriptionRules/output/GDP/so_full"
# Analyze execution time break down 
execTimeBreakDown(output_path)
